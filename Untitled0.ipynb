# %% [markdown]
# <a href="https://colab.research.google.com/github/abduofficial/Visual/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  **Installing required libraies**

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.9/976.9 kB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# # **Importing the model**

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# # **Importing the dataset**

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="EGglGAud91gvWrb2ZjWl")
project = rf.workspace("sit-asmsw").project("road-sign-detection-in-real-time")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Road-Sign-Detection-in-Real-Time-5 in yolov8:: 100%|██████████| 15972/15972 [00:02<00:00, 7133.80it/s]

# %% [markdown]
# # **Training the dataset**

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/Road-Sign-Detection-in-Real-Time-5/data.yaml epochs=90 imgsz=640 plots=True
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 539MB/s]
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=600)

# %%
from ultralytics import YOLO
model=YOLO('/content/runs/detect/train/weights/best.pt')

# Replace 'path/to/your/image.jpg' with the actual path to your image
model.predict(source='/content/images/WIN_20250331_23_57_16_Pro.jpg', imgsz=640,conf=0.4,save=True)
# Out:
# image 1/1 /content/images/WIN_20250331_23_57_16_Pro.jpg: 384x640 1 Stop, 2453.4ms
# Speed: 2.3ms preprocess, 2453.4ms inference, 117.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-79845fc6e574> in <cell line: 0>()
# ----> 1 files.download('/content/runs')
#
# NameError: name 'files' is not defined
